# %%
import pandas as pd

# popList = [56286961, 5463300, 3152879, 1893667]
# print(popList)

cNames= pd.Series(["England", "Scotland", "Wales", "Northern Ireland"])
# print (cNames)


df = pd.DataFrame()
df["country"] = cNames
pop = pd.Series([56286961, 5463300, 3152879, 1893667])
df["pop"] = pop
print(df)

# print(df.iloc[0:1])

# #Select all rows for columns starting at 0 and up to, but not including, column 1
# print(df.iloc[:,0:1])
# #Select all rows and all columns
# print(df.iloc[:,:])

# Access a single element as an indexed DataFrame or as a single value.
# print(df.iloc[0:1,1:2])
# print(df.iloc[0,1])

# Conditional access to a set of rows based on column values.
# print(df[df["pop"] < 50000000])


#Sort dataframes by specific column values.
df.sort_values(by="pop", ascending= True, inplace=True )
print(df)


# Note we have changed the index... this means we will not index by
# the newly sorted order, fix by resetting the index
df.reset_index(drop=True, inplace=True)
print(df)

df.sort_values( by="country", ascending = True, inplace=True )
print(df)

df.reset_index(drop=True, inplace=True)
print(df)
# Out:
#             country       pop
# 0           England  56286961
# 1          Scotland   5463300
# 2             Wales   3152879
# 3  Northern Ireland   1893667
#             country       pop
# 3  Northern Ireland   1893667
# 2             Wales   3152879
# 1          Scotland   5463300
# 0           England  56286961
#             country       pop
# 0  Northern Ireland   1893667
# 1             Wales   3152879
# 2          Scotland   5463300
# 3           England  56286961
#             country       pop
# 3           England  56286961
# 0  Northern Ireland   1893667
# 2          Scotland   5463300
# 1             Wales   3152879
#             country       pop
# 0           England  56286961
# 1  Northern Ireland   1893667
# 2          Scotland   5463300
# 3             Wales   3152879

# %%
import altair as alt
#Load excel data as pandas DataFrame
imd_df = pd.read_excel('./NorthEast_Domains_of_deprivation.xlsx')
imd_df.head(10)
# Out:
#   LSOA code (2011)    LSOA name (2011) Local Authority District code (2013)  \
# 0        E01020634  County Durham 001A                            E06000047
# 1        E01020635  County Durham 001B                            E06000047
# 2        E01020636  County Durham 001C                            E06000047
# 3        E01020654  County Durham 001D                            E06000047
# 4        E01020676  County Durham 001E                            E06000047
# 5        E01020613  County Durham 002A                            E06000047
# 6        E01020614  County Durham 002B                            E06000047
# 7        E01020622  County Durham 002C                            E06000047
# 8        E01020623  County Durham 002D                            E06000047
# 9        E01020627  County Durham 003A                            E06000047
#
#   Local Authority District name (2013)  \
# 0                        County Durham
# 1                        County Durham
# 2                        County Durham
# 3                        County Durham
# 4                        County Durham
# 5                        County Durham
# 6                        County Durham
# 7                        County Durham
# 8                        County Durham
# 9                        County Durham
#
#    Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)  \
# 0                                              28215
# 1                                              27967
# 2                                              12979
# 3                                              20852
# 4                                              17628
# 5                                              29774
# 6                                              13071
# 7                                              25545
# 8                                              25387
# 9                                              21720
#
#    Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  9
# 1                                                  9
# 2                                                  4
# 3                                                  7
# 4                                                  6
# 5                                                 10
# 6                                                  4
# 7                                                  8
# 8                                                  8
# 9                                                  7
#
#    Income Rank (where 1 is most deprived)  \
# 0                                   22425
# 1                                   26441
# 2                                    9118
# 3                                   17514
# 4                                   15852
# 5                                   28924
# 6                                   12017
# 7                                   25240
# 8                                   28472
# 9                                   17203
#
#    Income Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  7
# 1                                                  9
# 2                                                  3
# 3                                                  6
# 4                                                  5
# 5                                                  9
# 6                                                  4
# 7                                                  8
# 8                                                  9
# 9                                                  6
#
#    Employment Rank (where 1 is most deprived)  \
# 0                                       23105
# 1                                       22153
# 2                                        9104
# 3                                       16026
# 4                                       11432
# 5                                       26426
# 6                                        8049
# 7                                       23096
# 8                                       21950
# 9                                       14605
#
#    Employment Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  8
# 1                                                  7
# 2                                                  3
# 3                                                  5
# 4                                                  4
# 5                                                  9
# 6                                                  3
# 7                                                  8
# 8                                                  7
# 9                                                  5
#
#    Education, Skills and Training Rank (where 1 is most deprived)  \
# 0                                              29750
# 1                                              28008
# 2                                              10677
# 3                                              22207
# 4                                              19415
# 5                                              23953
# 6                                              16029
# 7                                              22355
# 8                                              25012
# 9                                              25269
#
#    Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                  9
# 2                                                  4
# 3                                                  7
# 4                                                  6
# 5                                                  8
# 6                                                  5
# 7                                                  7
# 8                                                  8
# 9                                                  8
#
#    Health Deprivation and Disability Rank (where 1 is most deprived)  \
# 0                                              16194
# 1                                              20348
# 2                                               8137
# 3                                              10808
# 4                                              11388
# 5                                              18632
# 6                                               4126
# 7                                              19252
# 8                                              16097
# 9                                              13156
#
#    Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  5
# 1                                                  7
# 2                                                  3
# 3                                                  4
# 4                                                  4
# 5                                                  6
# 6                                                  2
# 7                                                  6
# 8                                                  5
# 9                                                  5
#
#    Crime Rank (where 1 is most deprived)  \
# 0                                  30109
# 1                                  29834
# 2                                  23310
# 3                                  28634
# 4                                  27687
# 5                                  25158
# 6                                  26404
# 7                                  18621
# 8                                  29566
# 9                                  28576
#
#    Crime Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                 10
# 2                                                  8
# 3                                                  9
# 4                                                  9
# 5                                                  8
# 6                                                  9
# 7                                                  6
# 8                                                 10
# 9                                                  9
#
#    Barriers to Housing and Services Rank (where 1 is most deprived)  \
# 0                                              26994
# 1                                              16088
# 2                                              27725
# 3                                              20411
# 4                                              15746
# 5                                              28974
# 6                                              28947
# 7                                              16388
# 8                                               7766
# 9                                              22923
#
#    Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  9
# 1                                                  5
# 2                                                  9
# 3                                                  7
# 4                                                  5
# 5                                                  9
# 6                                                  9
# 7                                                  5
# 8                                                  3
# 9                                                  7
#
#    Living Environment Rank (where 1 is most deprived)  \
# 0                                              32395
# 1                                              29253
# 2                                              32803
# 3                                              30677
# 4                                              29267
# 5                                              29907
# 6                                              28972
# 7                                              28154
# 8                                              32181
# 9                                              32264
#
#    Living Environment Decile (where 1 is most deprived 10% of LSOAs)
# 0                                                 10
# 1                                                  9
# 2                                                 10
# 3                                                 10
# 4                                                  9
# 5                                                 10
# 6                                                  9
# 7                                                  9
# 8                                                 10
# 9                                                 10

# %%
imd_df.dtypes
# Out:
# LSOA code (2011)                                                                      object
# LSOA name (2011)                                                                      object
# Local Authority District code (2013)                                                  object
# Local Authority District name (2013)                                                  object
# Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)                    int64
# Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)     int64
# Income Rank (where 1 is most deprived)                                                 int64
# Income Decile (where 1 is most deprived 10% of LSOAs)                                  int64
# Employment Rank (where 1 is most deprived)                                             int64
# Employment Decile (where 1 is most deprived 10% of LSOAs)                              int64
# Education, Skills and Training Rank (where 1 is most deprived)                         int64
# Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)          int64
# Health Deprivation and Disability Rank (where 1 is most deprived)                      int64
# Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)       int64
# Crime Rank (where 1 is most deprived)                                                  int64
# Crime Decile (where 1 is most deprived 10% of LSOAs)                                   int64
# Barriers to Housing and Services Rank (where 1 is most deprived)                       int64
# Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)        int64
# Living Environment Rank (where 1 is most deprived)                                     int64
# Living Environment Decile (where 1 is most deprived 10% of LSOAs)                      int64
# dtype: object

# %%
#Rename variables
imd_df.rename(columns = {'Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)': 'IMD Rank',
'Income Rank (where 1 is most deprived)':'Income Rank',
'Employment Rank (where 1 is most deprived)':'Employment Rank',
'Education, Skills and Training Rank (where 1 is most deprived)':'Education Rank',
'Health Deprivation and Disability Rank (where 1 is most deprived)':'Health Rank',
'Crime Rank (where 1 is most deprived)':'Crime Rank',
'Barriers to Housing and Services Rank (where 1 is most deprived)':'Housing Rank',
'Living Environment Rank (where 1 is most deprived)':'Living Environment Rank',
'Local Authority District name (2013)':'District Name'
}, inplace = True)

imd_df.head(10)
# Out:
#   LSOA code (2011)    LSOA name (2011) Local Authority District code (2013)  \
# 0        E01020634  County Durham 001A                            E06000047
# 1        E01020635  County Durham 001B                            E06000047
# 2        E01020636  County Durham 001C                            E06000047
# 3        E01020654  County Durham 001D                            E06000047
# 4        E01020676  County Durham 001E                            E06000047
# 5        E01020613  County Durham 002A                            E06000047
# 6        E01020614  County Durham 002B                            E06000047
# 7        E01020622  County Durham 002C                            E06000047
# 8        E01020623  County Durham 002D                            E06000047
# 9        E01020627  County Durham 003A                            E06000047
#
#    District Name  IMD Rank  \
# 0  County Durham     28215
# 1  County Durham     27967
# 2  County Durham     12979
# 3  County Durham     20852
# 4  County Durham     17628
# 5  County Durham     29774
# 6  County Durham     13071
# 7  County Durham     25545
# 8  County Durham     25387
# 9  County Durham     21720
#
#    Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  9
# 1                                                  9
# 2                                                  4
# 3                                                  7
# 4                                                  6
# 5                                                 10
# 6                                                  4
# 7                                                  8
# 8                                                  8
# 9                                                  7
#
#    Income Rank  Income Decile (where 1 is most deprived 10% of LSOAs)  \
# 0        22425                                                  7
# 1        26441                                                  9
# 2         9118                                                  3
# 3        17514                                                  6
# 4        15852                                                  5
# 5        28924                                                  9
# 6        12017                                                  4
# 7        25240                                                  8
# 8        28472                                                  9
# 9        17203                                                  6
#
#    Employment Rank  Employment Decile (where 1 is most deprived 10% of LSOAs)  \
# 0            23105                                                  8
# 1            22153                                                  7
# 2             9104                                                  3
# 3            16026                                                  5
# 4            11432                                                  4
# 5            26426                                                  9
# 6             8049                                                  3
# 7            23096                                                  8
# 8            21950                                                  7
# 9            14605                                                  5
#
#    Education Rank  \
# 0           29750
# 1           28008
# 2           10677
# 3           22207
# 4           19415
# 5           23953
# 6           16029
# 7           22355
# 8           25012
# 9           25269
#
#    Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                  9
# 2                                                  4
# 3                                                  7
# 4                                                  6
# 5                                                  8
# 6                                                  5
# 7                                                  7
# 8                                                  8
# 9                                                  8
#
#    Health Rank  \
# 0        16194
# 1        20348
# 2         8137
# 3        10808
# 4        11388
# 5        18632
# 6         4126
# 7        19252
# 8        16097
# 9        13156
#
#    Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  5
# 1                                                  7
# 2                                                  3
# 3                                                  4
# 4                                                  4
# 5                                                  6
# 6                                                  2
# 7                                                  6
# 8                                                  5
# 9                                                  5
#
#    Crime Rank  Crime Decile (where 1 is most deprived 10% of LSOAs)  \
# 0       30109                                                 10
# 1       29834                                                 10
# 2       23310                                                  8
# 3       28634                                                  9
# 4       27687                                                  9
# 5       25158                                                  8
# 6       26404                                                  9
# 7       18621                                                  6
# 8       29566                                                 10
# 9       28576                                                  9
#
#    Housing Rank  \
# 0         26994
# 1         16088
# 2         27725
# 3         20411
# 4         15746
# 5         28974
# 6         28947
# 7         16388
# 8          7766
# 9         22923
#
#    Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  9
# 1                                                  5
# 2                                                  9
# 3                                                  7
# 4                                                  5
# 5                                                  9
# 6                                                  9
# 7                                                  5
# 8                                                  3
# 9                                                  7
#
#    Living Environment Rank  \
# 0                    32395
# 1                    29253
# 2                    32803
# 3                    30677
# 4                    29267
# 5                    29907
# 6                    28972
# 7                    28154
# 8                    32181
# 9                    32264
#
#    Living Environment Decile (where 1 is most deprived 10% of LSOAs)
# 0                                                 10
# 1                                                  9
# 2                                                 10
# 3                                                 10
# 4                                                  9
# 5                                                 10
# 6                                                  9
# 7                                                  9
# 8                                                 10
# 9                                                 10

# %%
#Set up a scatter plot displaying the IMD Rank of the different districts
alt.Chart(imd_df).mark_point().encode(
    y='District Name',
    x='IMD Rank'
)
# Out:
# alt.Chart(...)
